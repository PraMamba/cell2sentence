# %% [markdown]
# # Tutorial notebook 4: Cell Type Prediction
#
# In this tutorial, we will demonstrate how to use a pretrained Cell2Sentence (C2S) model to perform cell type prediction on single-cell RNA sequencing datasets. Cell type prediction is a crucial step in single-cell analysis, allowing researchers to identify and classify different cell populations within a dataset. By leveraging the power of C2S models, we can make accurate predictions based on the information encoded in cell sentences.
#
# In this tutorial, you will:
# 1. Load an immune tissue single-cell dataset from Domínguez Conde et al. (preprocessed in tutorial notebook 0, two sample donors)
#     - Citation: Domínguez Conde, C., et al. "Cross-tissue immune cell analysis reveals tissue-specific features in humans." Science 376.6594 (2022): eabl5197.
# 2. Load a pretrained C2S model that is capable of making cell type predictions.
# 3. Use the model to predict cell types based on the cell sentences derived from the dataset.

# %% [markdown]
# We will begin by importing the necessary libraries. These include Python's built-in libraries, third-party libraries for handling numerical computations, progress tracking, and specific libraries for single-cell RNA sequencing data and C2S operations.

# %%
# Python built-in libraries
import os
import pickle
import random
from collections import Counter

# Third-party libraries
import numpy as np
from tqdm import tqdm

# Single-cell libraries
import anndata
import scanpy as sc

# Cell2Sentence imports
import cell2sentence as cs
from cell2sentence.tasks import predict_cell_types_of_data

# %%
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# # Load Data
#
# Next, we will load the preprocessed dataset from the tutorial 0. This dataset has already been filtered and normalized, so it it ready for transformation into cell sentences.
#
# <font color='red'>Please make sure you have completed the preprocessing steps in Tutorial 0 before running the following code, if you are using your own dataset.</font>. Ensure that the file path is correctly set in <font color='gold'>DATA_PATH</font> to where your preprocessed data was saved from tutorial 0.

# %%
DATA_PATH = "/data/yy/test/D099_processed.h5ad"

# %%
import pandas as pd

adata = anndata.read_h5ad(DATA_PATH )

gene_df = pd.read_csv("/home/scbjtfy/RVQ-Alpha/data_utils/gene_name_list_with_index.csv")
gene_df["Index"] = gene_df["Index"].astype(int)

# 按 Index 排序
gene_df = gene_df.sort_values("Index")

# 重命名列
gene_df = gene_df.rename(columns={
    "Gene_Name": "gene_name",
    "Gene_ID": "ensembl_id"
})

# 设置 var
adata.var = gene_df.set_index("Index")[["gene_name", "ensembl_id"]]

# 把 var_names 替换成 gene_name
adata.var_names = adata.var["gene_name"].values

# 确保 var_names 的唯一性
adata.var_names_make_unique()

adata
# Out:
# /home/scbjtfy/anaconda3/envs/Axolotl/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
# AnnData object with n_obs × n_vars = 15806 × 36601
#     obs: 'donor_id', 'batch', 'author_cell_type', 'disease', 'tissue'
#     var: 'gene_name', 'ensembl_id'

# %%
adata.obs = adata.obs[["cell_type", "tissue", "batch_condition", "organism", "sex"]]

# %%
adata.obs
# Out:
#                             donor_id     batch       author_cell_type disease  \
# N2_O1_AAACGAAAGTCGCCAC-1          R1     O1_R1  Differentiating.Basal  normal
# N2_O1_AAACGAAGTTAGCTAC-1          R1     O1_R1  Differentiating.Basal  normal
# N2_O1_AAACGAATCCTCTCTT-1          R1     O1_R1  Differentiating.Basal  normal
# N2_O1_AAACGCTCACTGCACG-1          R1     O1_R1                  Basal  normal
# N2_O1_AAAGAACGTAGCTCGC-1          R1     O1_R1             Suprabasal  normal
# ...                              ...       ...                    ...     ...
# N3_ALIEX_TTTGATCTCAATCGGT-1       R2  ALIEX_R2              Secretory  normal
# N3_ALIEX_TTTGGAGCAAGCAGGT-1       R2  ALIEX_R2               Ciliated  normal
# N3_ALIEX_TTTGGTTGTATACCCA-1       R2  ALIEX_R2              Secretory  normal
# N3_ALIEX_TTTGGTTTCTGAATGC-1       R2  ALIEX_R2              Secretory  normal
# N3_ALIEX_TTTGTTGGTCGCATGC-1       R2  ALIEX_R2              Secretory  normal
#
#                             tissue
# N2_O1_AAACGAAAGTCGCCAC-1      lung
# N2_O1_AAACGAAGTTAGCTAC-1      lung
# N2_O1_AAACGAATCCTCTCTT-1      lung
# N2_O1_AAACGCTCACTGCACG-1      lung
# N2_O1_AAAGAACGTAGCTCGC-1      lung
# ...                            ...
# N3_ALIEX_TTTGATCTCAATCGGT-1   lung
# N3_ALIEX_TTTGGAGCAAGCAGGT-1   lung
# N3_ALIEX_TTTGGTTGTATACCCA-1   lung
# N3_ALIEX_TTTGGTTTCTGAATGC-1   lung
# N3_ALIEX_TTTGTTGGTCGCATGC-1   lung
#
# [15806 rows x 5 columns]

# %%
adata.var.head()
# Out:
#                gene_name       ensembl_id
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485
# FAM138A          FAM138A  ENSG00000237613
# OR4F5              OR4F5  ENSG00000186092
# AL627309.1    AL627309.1  ENSG00000238009
# AL627309.3    AL627309.3  ENSG00000239945

# %%
sc.pl.umap(
    adata,
    color="author_cell_type",
    size=8,
    title="Human Immune Tissue UMAP",
)

# %%
adata.X.max()

# %% [markdown]
# We are expecting log10 base 10 transformed data, with a maximum value somewhere around 3 or 4. Make sure to start with processed and normalized data when doing the cell sentence conversion!

# %% [markdown]
# # Cell2Sentence Conversion
#
# In this section, we will transform our AnnData object containing our single-cell dataset into a Cell2Sentence (C2S) dataset by calling the functions of the CSData class in the C2S code base. Full documentation for the functions of the CSData class can be found in the documentation page of C2S.

# %%
adata_obs_cols_to_keep = ["author_cell_type", "disease", "tissue"]

# %%
# Create CSData object
arrow_ds, vocabulary = cs.CSData.adata_to_arrow(
    adata=adata, 
    random_state=SEED, 
    sentence_delimiter=' ',
    label_col_names=adata_obs_cols_to_keep
)
# Out:
# WARN: more variables (36601) than observations (15806)... did you mean to transpose the object (e.g. adata.T)?
# WARN: more variables (36601) than observations (15806), did you mean to transpose the object (e.g. adata.T)?
# 100%|██████████| 15806/15806 [01:05<00:00, 241.59it/s]

# %%
arrow_ds
# Out:
# Dataset({
#     features: ['cell_name', 'cell_sentence', 'author_cell_type', 'disease', 'tissue'],
#     num_rows: 15806
# })

# %%
sample_idx = 1199
arrow_ds[sample_idx]
# Out:
# {'cell_name': 'N2_O1_GAGTTGTTCTCAAAGC-1',
#  'cell_sentence': 'MALAT1 MT-CO2 MT-CO3 MT-CO1 MT-ATP6 KRT19 MT-CYB S100A6 S100A2 RPS2 S100A11 GAPDH RPS18 RPL13 EEF1A1 SERPINB1 KRT6A MT-ND4 RPL10 RPL7A ANXA2 RPS8 RPLP1 TMSB10 RPS14 SERPINB3 TPT1 RPL8 RPL17 RPL11 RPS6 RPS23 RPL13A KRT8 RPL12 RPL29 RPS12 RPS3A RPL15 RPS27A RPL26 S100A10 RPL41 RPS19 RPL3 RPL18 RPS3 RPS7 KRT18 S100A14 RPL5 RACK1 MIF RPL19 RPL6 RPS4X RPL28 GSTP1 RPL32 RPL18A CSTB MT-ND1 RPS24 MT-ND3 RPS15 RPS16 RPL9 S100A16 RPL23A RPLP0 ACTG1 RPSA RPS15A RPL30 MT-ND2 RPL10A RPL14 RPL27A RPS9 RPS28 RPL35A KRT17 RPL34 RPL37A TXN RPS13 TPI1 RPL24 RPL35 RPL7 LDHA RPS27 ENO1 FTH1 RPS5 SAT1 RPL21 NACA RPL39 RPL36 RPLP2 NEAT1 RPS11 FXYD3 RPL37 ACTB EEF1G EIF1 KRT13 RPS25 RPS29 PPIA HINT1 TMSB4X RPS17 EEF1B2 CALM1 FAU PTMA H3F3B H3F3A PERP COX4I1 UBA52 RPL22 NPM1 DHRS9 KRT15 RPS21 NME2 PPDPF EIF4A1 PKM PHLDA2 HSP90AA1 ATP5MC3 BTF3 RPL38 FGFBP1 GAS5 TKT SNHG29 KRT7 RPL27 RPS20 RPL36A RPL23 MT-ND5 RPL4 IGFBP2 SLC25A6 CAST MIR31HG SERF2 ADIRF CD9 SLC25A3 ATP5F1E HSP90AB1 PGK1 KRT6B DYNLL1 ATP1B3 EEF1D MIR205HG MYL6 CCND1 YBX1 UQCRB ALDH3A1 PRDX1 MYL12B ATP5MC2 SPINT2 SFN EIF3K UQCRH HSPB1 SERPINB4 RAN ARPC3 ARPC2 TSPO RPL31 LDHB CST3 ELOB CHCHD2 COX7A2 COX7C COX5B PPA1 NDUFS5 ITM2B NDUFA4L2 PPP1R14B RPS26 SELENOW PSMA7 FAM162A HSPD1 SLC25A5 ANXA1 TAGLN2 CFL1 ATP5ME COMT OAZ1 NDUFA13 SH3BGRL3 COX5A EREG GSN RPS4Y1 LGALS3 THRB ATP5F1D ATP5MG PFN1 PRDX2 MGST1 EDF1 COX6B1 C1QBP YWHAZ CD63 ATP5F1B SRP14 LMNA HSPE1 COX8A IER3 DSTN APRT SUMO2 TMEM45B SEC61G UBC CCT2 EID1 PA2G4 RIN2 RPS10 SNRPD2 KLF5 CLIC1 POLD4 MRPS24 EIF3E CLDN4 VDAC2 EEF2 PRDX5 TSPAN1 CIB1 GPX4 H2AFZ ATP5MD ATP1B1 DSG3 EIF2S2 YWHAE EIF5A ATP6V1G1 ATP5MPL RAC1 TMA7 UQCR10 ATP5IF1 CASC19 DDX5 CEMIP MT-ATP8 SRSF3 COX6A1 HIGD2A B2M EMP2 CD109 CSNK1A1 PHB2 HSPA8 GUK1 CCT3 PRDX6 EFHD2 HMGA1 PABPC1 ATP5PO NDUFA11 ATP5PF PSMD8 NUCKS1 NPC2 CALM2 PRELID1 SF3B6 HNRNPA2B1 HMGB1 TACSTD2 DBI GNAS MYOF CYCS C4ORF3 TOMM20 HES1 WASF2 PSMB1 SELENOH FRMD6 ECH1 TXNDC17 ID1 CHCHD10 COX6C UQCR11 CLTA BTG1 NDUFB2 KIAA1217 SOD1 SNU13 DSP EIF3I SRSF9 XRCC5 MTRNR2L12 SERBP1 SSR4 SERINC5 RPL36AL PDCD5 CEBPD NCL CLCA2 SAP18 TSTD1 TIMM13 NDUFB8 RAB10 HEBP2 PFDN2 PARK7 HLA-A KRT5 SYPL1 CYB5A CYC1 C19ORF33 PPP1CA ARL6IP4 C19ORF53 ATP5PB SKP1 SERPINB5 SEM1 TOMM6 SUB1 POMP POLR2L PEBP1 TRMT112 NDUFV2 RNASEK MT1X RBM25 EGFR ANP32B CTNND1 NDUFAB1 FIS1 NDUFS8 RHOC CNBP CCNI SH3PXD2A LPP PPIB RHOV EIF3A LGALS1 UBB FTL PTPRZ1 NDUFA4 ATP5F1C ADAM10 CTSB PSMA1 MRPS21 UQCC2 ATP5PD TBCA COX7B COMMD6 NDUFB11 UQCRQ ZFAS1 EIF6 LGALS7B ATP5MC1 HNRNPA1 CBX3 EIF3F CD59 ZCCHC7 TRIR RBX1 NDUFS6 NDUFB7 TXNIP DDT NFE2L2 MAP3K5 BARX2 RNH1 FUS UQCRC2 PAM MTDH CYBA UQCRFS1 DBNL ATP5MF TENM4 MT2A YBX3 MICOS10 TALDO1 CCT8 CCT5 PLP2 CIRBP FAM3C RANBP1 ATP6V1F NQO1 SEC61B BAIAP2 MRPL4 MGST3 RBM8A SSB G3BP1 MT-ND4L CSTA PRMT1 NAP1L1 ACADVL RBP1 AKR1C3 ETHE1 NDUFC2 OLA1 MLF2 NRG1 NDUFB4 GADD45GIP1 IMMP2L RAB25 CDK6 YWHAB CSDE1 NDUFB10 FOXP1 TMEM141 SSBP1 OCIAD2 MDH2 ADK TMEM134 HSP90B1 PHPT1 SNRPD1 SIPA1L1 TOMM7 JUNB B4GALT5 ID3 ADH5 HNRNPR CHMP2A GSTO1 ATXN10 SPINK5 EIF1AX ECHS1 RAD50 JPT1 RBMX OCIAD1 PSMA6 PON2 TOP1 AC090004.2 CCT4 S100A4 ARF1 KRT16 EZR GJB2 SNRPF ARPC5 AGR2 TUBB4B PLPP2 C9ORF16 CAPG RREB1 TBL1XR1 PNISR ERH PFDN5 TPM4 ENSA HNRNPA3 VPS28 CTSD YWHAQ MRPL41 IER2 RCOR1 TANC1 SNRPE NOP10 CD99 MBNL1 PCBP2 MKNK2 PDAP1 MYL12A C16ORF74 PSMA2 ARHGAP32 SNHG7 LSM7 COX7A2L SET TMPRSS4 HPGD GCHFR PSMA4 GPI PELI1 TRAPPC1 TECR JUP NDUFS7 LAMTOR1 BSG NDUFA8 LAMTOR5 CTSC WWTR1 LARP4B JUND ARPC1B AKR7A2 COL4A5 RBM39 UBE2L3 LUC7L3 ATP5F1A TPM3 THRAP3 EIF4EBP1 PTGES3 NDUFA10 ENDOG STRAP ANAPC16 ROMO1 KTN1 PGLS RAB2A BRK1 MRPS7 RBIS CCT6A EIF3H NDUFB3 SNHG8 GOT1 MRPL20 RAD23B SDC1 IKZF2 HIF1A CAPS LSM2 UBE2D2 GLRX3 FBL POLR2E TMBIM6 FHIT GTF2I SSNA1 SLIRP GPX2 SLC12A2 DNPH1 EGLN3 EIF3G OST4 DCTN3 HMGN1 VAMP8 SRRM2 VPS29 SRSF5 ZBTB7C TNFRSF12A NDUFS2 ERBIN ASPH TANK HMGN2 EHF AOPEP VAPA GALNT1 MRPS34 UBL5 PSMB3 EIF5B CHCHD1 TAF10 TMED9 PSMC5 TUFM ALKBH7 CAPN2 DAD1 MACF1 GGCT SDHB C11ORF58 PIR UQCRC1 KRTCAP3 FABP5 MRPS16 POLR ...
#  'author_cell_type': 'Differentiating.Basal',
#  'disease': 'normal',
#  'tissue': 'lung'}

# %%
arrow_ds['author_cell_type']
# Out:
# Column(['Differentiating.Basal', 'Differentiating.Basal', 'Differentiating.Basal', 'Basal', 'Suprabasal'])

# %% [markdown]
# This time, we will leave off creating our CSData object until after we load our C2S model. This is because along with the model checkpoint, we saved the indices of train, val, and test set cells, which will allow us to select out test set cells for inference.

# %% [markdown]
# # Load C2S Model
#
# Now, we will load a C2S model with which we will do cell type annotation. For this tutorial, this model will be the last checkpoint of the training session from <font color="red">tutorial notebook 3</font>, where we finetuned our cell type prediction model to do cell type prediction specifically on our immune tissue dataset. We will load the last checkpoint saved from training, and specify the same save_dir as we used before during training.
# - <font color="red">Note:</font> If you are using your own data for this tutorial, make sure to switch out to the model checkpoint which you saved in tutorial notebook 3.
# - If you want to annotate cell types without finetuning your own C2S model, then tutorial notebook 6 demonstrates how to load the C2S-Pythia-410M cell type prediction foundation model and use it to predict cell types without any finetuning.
#
# We can define our CSModel object with our pretrained cell type prediction model as follows, specifying the same save_dir as we used in tutorial 3:

# %%
# Define CSModel object
cell_type_prediction_model_path = "/data/Mamba/Data/hf_cache/hub/models--vandijklab--C2S-Pythia-410m-cell-type-prediction/snapshots/5a4dc3b949b5868ca63752b37bc22e3b0216e435"
save_dir = "./"
save_name = "cell_type_pred_pythia_410M_inference"
csmodel = cs.CSModel(
    model_name_or_path=cell_type_prediction_model_path,
    save_dir=save_dir,
    save_name=save_name
)
# Out:
# Using device: cuda
# [2025-09-29 15:53:57,236] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: warning: librt.so.1, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: warning: libpthread.so.0, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: warning: libstdc++.so.6, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: warning: libm.so.6, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::runtime_error::~runtime_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__gxx_personality_v0@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::tellp()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::chrono::_V2::steady_clock::now()@GLIBCXX_3.4.19'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_replace_aux(unsigned long, unsigned long, unsigned long, char)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for bool@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_logic_error(char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::logic_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::~locale()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::string const&, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_end_catch@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::logic_error::~logic_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__si_class_type_info@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::_M_cache_locale(std::locale const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator new[](unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_leak_hard()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >::basic_streambuf(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> > const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(char const*, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::string const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned short@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::resize(unsigned long, char)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for char const*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ctype<char>::_M_widen_init() const@GLIBCXX_3.4.11'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_invalid_argument(char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::operator=(std::locale const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<wchar_t, std::char_traits<wchar_t> >::_M_cache_locale(std::locale const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_free_exception@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::condition_variable::notify_one()@GLIBCXX_3.4.11'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::Init::~Init()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::~basic_string()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_pure_virtual@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::flush()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__class_type_info@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_rethrow@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_fstream<char, std::char_traits<char> >::~basic_fstream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::compare(char const*) const@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ostringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::locale()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::chrono::_V2::system_clock::now()@GLIBCXX_3.4.19'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Hash_bytes(void const*, unsigned long, unsigned long)@CXXABI_1.3.5'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long long>(long long)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for char*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_Prime_rehash_policy::_M_need_rehash(unsigned long, unsigned long, unsigned long) const@GLIBCXX_3.4.18'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::out_of_range@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long>(unsigned long)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::~ios_base()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::range_error::~range_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::~__basic_file()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_guard_acquire@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<bool>(bool)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::overflow_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::range_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ios<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_filebuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator delete[](void*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(unsigned long, char, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_transfer(std::__detail::_List_node_base*, std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::replace(unsigned long, unsigned long, char const*, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for std::exception@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_Rep::_M_destroy(std::allocator<wchar_t> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream& std::istream::_M_extract<double>(double&)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::basic_ifstream(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(std::string const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator new(unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_istringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned int@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::domain_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::find(char, unsigned long) const@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::put(char)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for int@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_bad_alloc()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_thread_atexit@CXXABI_1.3.7'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned int*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::~basic_ifstream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::Init::Init()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::condition_variable::condition_variable()@GLIBCXX_3.4.11'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::basic_filebuf()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::domain_error::~domain_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::cerr@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::find(char const*, unsigned long, unsigned long) const@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::allocator<char> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::str() const@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::invalid_argument@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for void*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::assign(std::string const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_ostringstream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_rebalance_for_erase(std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_hook(std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_unhook()@GLIBCXX_3.4.15'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ostringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::_M_sync(char*, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_iostream<char, std::char_traits<char> >::~basic_iostream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::locale(std::locale const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_istringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `log2f@GLIBC_2.2.5'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::exception::~exception()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_create(unsigned long, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::is_open() const@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_istringstream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::swap(std::string&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_streambuf<char, std::char_traits<char> >::basic_streambuf(std::basic_streambuf<char, std::char_traits<char> > const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::init(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_bad_cast()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::clear(std::_Ios_Iostate)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >::operator=(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> > const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for long*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator delete(void*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(int)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_empty_rep_storage@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_M_destroy(std::allocator<char> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_iostream<wchar_t, std::char_traits<wchar_t> >::~basic_iostream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::runtime_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_insert_and_rebalance(bool, std::_Rb_tree_node_base*, std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_stringstream()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_stringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long>(long)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream::get()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long long@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::operator<< <std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::out_of_range::~out_of_range()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::length_error::~length_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::__ostream_insert<char, std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*, long)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::invalid_argument::~invalid_argument()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::swap(std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::cout@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long long>(unsigned long long)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<void const*>(void const*)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::underflow_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_streambuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for std::out_of_range@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_allocate_exception@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ios<wchar_t, std::char_traits<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for void const*@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<wchar_t, std::char_traits<wchar_t> >::init(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::reserve(unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_begin_catch@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for long@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_Rep::_S_empty_rep_storage@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_leak()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::open(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_M_sync(wchar_t*, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream::getline(char*, long, char)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_istream<char, std::char_traits<char> >& std::getline<char, std::char_traits<char>, std::allocator<char> >(std::basic_istream<char, std::char_traits<char> >&, std::basic_string<char, std::char_traits<char>, std::allocator<char> >&, char)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::condition_variable::~condition_variable()@GLIBCXX_3.4.11'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringbuf<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::insert(unsigned long, char const*, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::assign(char const*, unsigned long)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned char@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::ios_base()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_out_of_range(char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::overflow_error::~overflow_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_length_error(char const*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_system_error(int)@GLIBCXX_3.4.11'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ofstream<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<double>(double)@GLIBCXX_3.4.9'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_streambuf<char, std::char_traits<char> >::operator=(std::basic_streambuf<char, std::char_traits<char> > const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for long long@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(char const*, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_guard_release@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_throw@CXXABI_1.3'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::underflow_error::~underflow_error()@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::length_error@GLIBCXX_3.4'
# /home/scbjtfy/anaconda3/envs/Axolotl/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::~basic_filebuf()@GLIBCXX_3.4'
# collect2: error: ld returned 1 exit status
# [2025-09-29 15:53:57,981] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False

# %% [markdown]
# We will also load the data split indices saved alongside the C2S model checkpoint, so that we know which cells were part of the training and validation set. We will do inference on unseen test set cells, which are 10% of the original data.

# %%
base_path = "/".join(cell_type_prediction_model_path.split("/")[:-1])
print(cell_type_prediction_model_path)
print(base_path)
# Out:
# /data/Mamba/Data/hf_cache/hub/models--vandijklab--C2S-Pythia-410m-cell-type-prediction/snapshots/5a4dc3b949b5868ca63752b37bc22e3b0216e435
# /data/Mamba/Data/hf_cache/hub/models--vandijklab--C2S-Pythia-410m-cell-type-prediction/snapshots

# %% [markdown]
# Select out test set cells from full arrow dataset

# %%
arrow_ds
# Out:
# Dataset({
#     features: ['cell_name', 'cell_sentence', 'author_cell_type', 'disease', 'tissue'],
#     num_rows: 15806
# })

# %%
test_ds = arrow_ds.select(range(1000))
test_ds
# Out:
# Dataset({
#     features: ['cell_name', 'cell_sentence', 'author_cell_type', 'disease', 'tissue'],
#     num_rows: 1000
# })

# %% [markdown]
# Now, we will create our CSData object using only the test set cells:

# %%
c2s_save_dir = "./"  # C2S dataset will be saved into this directory
c2s_save_name = "dominguez_immune_tissue_tutorial4"  # This will be the name of our C2S dataset on disk

# %%
csdata = cs.CSData.csdata_from_arrow(
    arrow_dataset=test_ds, 
    vocabulary=vocabulary,
    save_dir=c2s_save_dir,
    save_name=c2s_save_name,
    dataset_backend="arrow"
)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
print(csdata)

# %% [markdown]
# # Predict cell types
#
# Now that we have loaded our finetuned cell type prediction model and have our test set, we will do cell type prediction inference using our C2S model. We can use the function predict_cell_types_of_data() from the tasks.py, which will take a CSModel() object and apply it to do cell type prediction on a CSData() object.

# %%
predicted_cell_types = predict_cell_types_of_data(
    csdata=csdata,
    csmodel=csmodel,
    n_genes=200
)

# %%
len(predicted_cell_types)

# %%
predicted_cell_types[:3]

# %%
test_ds

# %%
total_correct = 0.0
for model_pred, gt_label in zip(predicted_cell_types, test_ds["cell_type"]):
    # C2S might predict a period at the end of the cell type, which we remove
    if model_pred[-1] == ".":
        model_pred = model_pred[:-1]
    
    if model_pred == gt_label:
        total_correct += 1

accuracy = total_correct / len(predicted_cell_types)

# %%
print("Accuracy:", accuracy)

# %%
for idx in range(0, 100, 10):
    print("Model pred: {}, GT label: {}".format(predicted_cell_types[idx], test_ds[idx]["cell_type"]))

# %% [markdown]
# We can see that our model achieves high accuracy, correctly predicting the cell type of unseen cells from the immune tissue data 83.4% of the time! The model learned to predict cell type annotations in natural language effectively from a short finetuning period on the new data.
